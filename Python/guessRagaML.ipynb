# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)
# X = le.fit_transform(np.array(X))


# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)
import pprint
for i in range(len(X)):
  print((X[i], y[i]))
print(len(X), len(y))
# Out:
# (array(['SSrgm'], dtype=object), 102)
# (array(['SSrGM'], dtype=object), 1)
# (array(['SSRgM'], dtype=object), 50)
# (array(['SSRGR'], dtype=object), 36)
# (array(['SSRGP'], dtype=object), 39)
# (array(['SSRMP'], dtype=object), 61)
# (array(['SSRmP'], dtype=object), 101)
# (array(['SSgMP'], dtype=object), 26)
# (array(['SSgMd'], dtype=object), 88)
# (array(['SSgMD'], dtype=object), 7)
# (array(['SSGMP'], dtype=object), 41)
# (array(['SSMGP'], dtype=object), 84)
# (array(['SSdnP'], dtype=object), 47)
# (array(['SSDPG'], dtype=object), 36)
# (array(['SSDPM'], dtype=object), 65)
# (array(['SSDPD'], dtype=object), 62)
# (array(['SSnPM'], dtype=object), 97)
# (array(['SSndM'], dtype=object), 86)
# (array(['SSndP'], dtype=object), 14)
# (array(['SSnDP'], dtype=object), 24)
# (array(['SSNPG'], dtype=object), 72)
# (array(['SSNdM'], dtype=object), 45)
# (array(['SSNdP'], dtype=object), 11)
# (array(['SSNDM'], dtype=object), 7)
# (array(['SSNDm'], dtype=object), 90)
# (array(['SSNDP'], dtype=object), 111)
# (array(['SrgrS'], dtype=object), 104)
# (array(['SrgMS'], dtype=object), 14)
# (array(['SrgMr'], dtype=object), 14)
# (array(['SrgMR'], dtype=object), 14)
# (array(['SrgMg'], dtype=object), 14)
# (array(['SrgMG'], dtype=object), 14)
# (array(['SrgMM'], dtype=object), 14)
# (array(['SrgMm'], dtype=object), 14)
# (array(['SrgMP'], dtype=object), 14)
# (array(['SrgMd'], dtype=object), 14)
# (array(['SrgMD'], dtype=object), 14)
# (array(['SrgMn'], dtype=object), 14)
# (array(['SrgMN'], dtype=object), 14)
# (array(['SrgmS'], dtype=object), 102)
# (array(['Srgmr'], dtype=object), 102)
# (array(['SrgmR'], dtype=object), 102)
# (array(['Srgmg'], dtype=object), 102)
# (array(['SrgmG'], dtype=object), 102)
# (array(['SrgmM'], dtype=object), 102)
# (array(['Srgmm'], dtype=object), 102)
# (array(['SrgmP'], dtype=object), 102)
# (array(['Srgmd'], dtype=object), 102)
# (array(['SrgmD'], dtype=object), 102)
# (array(['Srgmn'], dtype=object), 102)
# (array(['SrgmN'], dtype=object), 102)
# (array(['SrGrS'], dtype=object), 1)
# (array(['SrGMS'], dtype=object), 1)
# (array(['SrGMr'], dtype=object), 1)
# (array(['SrGMR'], dtype=object), 1)
# (array(['SrGMg'], dtype=object), 1)
# (array(['SrGMG'], dtype=object), 1)
# (array(['SrGMM'], dtype=object), 1)
# (array(['SrGMm'], dtype=object), 1)
# (array(['SrGMP'], dtype=object), 1)
# (array(['SrGMd'], dtype=object), 1)
# (array(['SrGMD'], dtype=object), 1)
# (array(['SrGMn'], dtype=object), 1)
# (array(['SrGMN'], dtype=object), 1)
# (array(['SrGmD'], dtype=object), 93)
# (array(['SRSRG'], dtype=object), 36)
# (array(['SRgRS'], dtype=object), 82)
# (array(['SRgMS'], dtype=object), 50)
# (array(['SRgMr'], dtype=object), 50)
# (array(['SRgMR'], dtype=object), 47)
# (array(['SRgMg'], dtype=object), 82)
# (array(['SRgMG'], dtype=object), 50)
# (array(['SRgMM'], dtype=object), 50)
# (array(['SRgMm'], dtype=object), 50)
# (array(['SRgMP'], dtype=object), 50)
# (array(['SRgMd'], dtype=object), 50)
# (array(['SRgMD'], dtype=object), 50)
# (array(['SRgMn'], dtype=object), 50)
# (array(['SRgMN'], dtype=object), 50)
# (array(['SRGRS'], dtype=object), 36)
# (array(['SRGRr'], dtype=object), 36)
# (array(['SRGRR'], dtype=object), 36)
# (array(['SRGRg'], dtype=object), 36)
# (array(['SRGRG'], dtype=object), 36)
# (array(['SRGRM'], dtype=object), 36)
# (array(['SRGRm'], dtype=object), 36)
# (array(['SRGRP'], dtype=object), 36)
# (array(['SRGRd'], dtype=object), 36)
# (array(['SRGRD'], dtype=object), 36)
# (array(['SRGRn'], dtype=object), 36)
# (array(['SRGRN'], dtype=object), 36)
# (array(['SRGmD'], dtype=object), 106)
# (array(['SRGPS'], dtype=object), 39)
# (array(['SRGPr'], dtype=object), 39)
# (array(['SRGPR'], dtype=object), 36)
# (array(['SRGPg'], dtype=object), 39)
# (array(['SRGPG'], dtype=object), 62)
# (array(['SRGPM'], dtype=object), 39)
# (array(['SRGPm'], dtype=object), 39)
# (array(['SRGPP'], dtype=object), 39)
# (array(['SRGPd'], dtype=object), 39)
# (array(['SRGPD'], dtype=object), 37)
# (array(['SRGPn'], dtype=object), 39)
# (array(['SRGPN'], dtype=object), 72)
# (array(['SRGNS'], dtype=object), 51)
# (array(['SRMRS'], dtype=object), 98)
# (array(['SRMgR'], dtype=object), 73)
# (array(['SRMGR'], dtype=object), 56)
# (array(['SRMPS'], dtype=object), 61)
# (array(['SRMPr'], dtype=object), 61)
# (array(['SRMPR'], dtype=object), 61)
# (array(['SRMPg'], dtype=object), 61)
# (array(['SRMPG'], dtype=object), 61)
# (array(['SRMPM'], dtype=object), 61)
# (array(['SRMPm'], dtype=object), 61)
# (array(['SRMPP'], dtype=object), 61)
# (array(['SRMPd'], dtype=object), 73)
# (array(['SRMPD'], dtype=object), 69)
# (array(['SRMPn'], dtype=object), 61)
# (array(['SRMPN'], dtype=object), 59)
# (array(['SRmRS'], dtype=object), 101)
# (array(['SRmPS'], dtype=object), 101)
# (array(['SRmPr'], dtype=object), 101)
# (array(['SRmPR'], dtype=object), 101)
# (array(['SRmPg'], dtype=object), 101)
# (array(['SRmPG'], dtype=object), 101)
# (array(['SRmPM'], dtype=object), 101)
# (array(['SRmPm'], dtype=object), 101)
# (array(['SRmPP'], dtype=object), 101)
# (array(['SRmPd'], dtype=object), 101)
# (array(['SRmPD'], dtype=object), 101)
# (array(['SRmPn'], dtype=object), 101)
# (array(['SRmPN'], dtype=object), 101)
# (array(['SgMRS'], dtype=object), 47)
# (array(['SgMgS'], dtype=object), 89)
# (array(['SgMgR'], dtype=object), 7)
# (array(['SgMgM'], dtype=object), 7)
# (array(['SgMPS'], dtype=object), 26)
# (array(['SgMPr'], dtype=object), 26)
# (array(['SgMPR'], dtype=object), 26)
# (array(['SgMPg'], dtype=object), 26)
# (array(['SgMPG'], dtype=object), 26)
# (array(['SgMPM'], dtype=object), 26)
# (array(['SgMPm'], dtype=object), 26)
# (array(['SgMPP'], dtype=object), 26)
# (array(['SgMPd'], dtype=object), 21)
# (array(['SgMPD'], dtype=object), 20)
# (array(['SgMPn'], dtype=object), 26)
# (array(['SgMPN'], dtype=object), 26)
# (array(['SgMdS'], dtype=object), 88)
# (array(['SgMdr'], dtype=object), 45)
# (array(['SgMdR'], dtype=object), 88)
# (array(['SgMdg'], dtype=object), 88)
# (array(['SgMdG'], dtype=object), 88)
# (array(['SgMdM'], dtype=object), 88)
# (array(['SgMdm'], dtype=object), 88)
# (array(['SgMdP'], dtype=object), 88)
# (array(['SgMdd'], dtype=object), 88)
# (array(['SgMdD'], dtype=object), 88)
# (array(['SgMdn'], dtype=object), 86)
# (array(['SgMdN'], dtype=object), 45)
# (array(['SgMDS'], dtype=object), 7)
# (array(['SgMDr'], dtype=object), 7)
# (array(['SgMDR'], dtype=object), 7)
# (array(['SgMDg'], dtype=object), 7)
# (array(['SgMDG'], dtype=object), 7)
# (array(['SgMDM'], dtype=object), 7)
# (array(['SgMDm'], dtype=object), 7)
# (array(['SgMDP'], dtype=object), 7)
# (array(['SgMDd'], dtype=object), 7)
# (array(['SgMDD'], dtype=object), 7)
# (array(['SgMDn'], dtype=object), 7)
# (array(['SgMDN'], dtype=object), 7)
# (array(['SgmPd'], dtype=object), 102)
# (array(['SGRGS'], dtype=object), 80)
# (array(['SGRGN'], dtype=object), 51)
# (array(['SGMGR'], dtype=object), 41)
# (array(['SGMGM'], dtype=object), 41)
# (array(['SGMPS'], dtype=object), 41)
# (array(['SGMPr'], dtype=object), 41)
# (array(['SGMPR'], dtype=object), 41)
# (array(['SGMPg'], dtype=object), 41)
# (array(['SGMPG'], dtype=object), 41)
# (array(['SGMPM'], dtype=object), 41)
# (array(['SGMPm'], dtype=object), 41)
# (array(['SGMPP'], dtype=object), 41)
# (array(['SGMPd'], dtype=object), 42)
# (array(['SGMPD'], dtype=object), 2)
# (array(['SGMPn'], dtype=object), 41)
# (array(['SGMPN'], dtype=object), 41)
# (array(['SGmrG'], dtype=object), 91)
# (array(['SGmDN'], dtype=object), 115)
# (array(['SGPGR'], dtype=object), 62)
# (array(['SGPmP'], dtype=object), 84)
# (array(['SGPDS'], dtype=object), 37)
# (array(['SGPNS'], dtype=object), 72)
# (array(['SMgrS'], dtype=object), 14)
# (array(['SMgRS'], dtype=object), 19)
# (array(['SMGrS'], dtype=object), 1)
# (array(['SMGRS'], dtype=object), 41)
# (array(['SMGRG'], dtype=object), 56)
# (array(['SMGPS'], dtype=object), 84)
# (array(['SMGPr'], dtype=object), 84)
# (array(['SMGPR'], dtype=object), 84)
# (array(['SMGPg'], dtype=object), 84)
# (array(['SMGPG'], dtype=object), 84)
# (array(['SMGPM'], dtype=object), 84)
# (array(['SMGPm'], dtype=object), 84)
# (array(['SMGPP'], dtype=object), 84)
# (array(['SMGPd'], dtype=object), 84)
# (array(['SMGPD'], dtype=object), 84)
# (array(['SMGPn'], dtype=object), 84)
# (array(['SMGPN'], dtype=object), 84)
# (array(['SMPgM'], dtype=object), 47)
# (array(['SMPdn'], dtype=object), 78)
# (array(['SMPdN'], dtype=object), 11)
# (array(['SMPDS'], dtype=object), 69)
# (array(['SMPDg'], dtype=object), 7)
# (array(['SMPDn'], dtype=object), 6)
# (array(['SMPnS'], dtype=object), 26)
# (array(['SMPNS'], dtype=object), 60)
# (array(['SMdnS'], dtype=object), 86)
# (array(['SMdNS'], dtype=object), 45)
# (array(['SMDnS'], dtype=object), 7)
# (array(['SmgrS'], dtype=object), 102)
# (array(['SmGrS'], dtype=object), 93)
# (array(['SmGRS'], dtype=object), 106)
# (array(['SmPGM'], dtype=object), 41)
# (array(['SmPdN'], dtype=object), 102)
# (array(['SmPDS'], dtype=object), 101)
# (array(['SmPDP'], dtype=object), 84)
# (array(['SmPDN'], dtype=object), 84)
# (array(['SmDNS'], dtype=object), 115)
# (array(['SPRGR'], dtype=object), 36)
# (array(['SPRGm'], dtype=object), 106)
# (array(['SPgMR'], dtype=object), 47)
# (array(['SPGRS'], dtype=object), 39)
# (array(['SPGMG'], dtype=object), 41)
# (array(['SPMRS'], dtype=object), 100)
# (array(['SPMgS'], dtype=object), 63)
# (array(['SPMgr'], dtype=object), 14)
# (array(['SPMgR'], dtype=object), 29)
# (array(['SPMGr'], dtype=object), 1)
# (array(['SPMGR'], dtype=object), 56)
# (array(['SPMPg'], dtype=object), 47)
# (array(['SPmRS'], dtype=object), 101)
# (array(['SPmgr'], dtype=object), 102)
# (array(['SPmGr'], dtype=object), 91)
# (array(['SPmGR'], dtype=object), 106)
# (array(['SPmPG'], dtype=object), 41)
# (array(['SPmPD'], dtype=object), 84)
# (array(['SPdnS'], dtype=object), 78)
# (array(['SPdNS'], dtype=object), 103)
# (array(['SPDgM'], dtype=object), 7)
# (array(['SPDGP'], dtype=object), 62)
# (array(['SPDPM'], dtype=object), 84)
# (array(['SPDnS'], dtype=object), 6)
# (array(['SPDNS'], dtype=object), 84)
# (array(['SPnSg'], dtype=object), 63)
# (array(['SdMgS'], dtype=object), 88)
# (array(['SdPMg'], dtype=object), 14)
# (array(['SdPMG'], dtype=object), 11)
# (array(['SdnSR'], dtype=object), 47)
# (array(['SdnSd'], dtype=object), 47)
# (array(['SdnPS'], dtype=object), 47)
# (array(['SdnPr'], dtype=object), 47)
# (array(['SdnPR'], dtype=object), 47)
# (array(['SdnPg'], dtype=object), 47)
# (array(['SdnPG'], dtype=object), 47)
# (array(['SdnPM'], dtype=object), 47)
# (array(['SdnPm'], dtype=object), 47)
# (array(['SdnPP'], dtype=object), 47)
# (array(['SdnPd'], dtype=object), 47)
# (array(['SdnPD'], dtype=object), 47)
# (array(['SdnPn'], dtype=object), 47)
# (array(['SdnPN'], dtype=object), 47)
# (array(['SDRSR'], dtype=object), 36)
# (array(['SDgMg'], dtype=object), 7)
# (array(['SDGPG'], dtype=object), 62)
# (array(['SDGPD'], dtype=object), 62)
# (array(['SDMPD'], dtype=object), 7)
# (array(['SDmGr'], dtype=object), 90)
# (array(['SDPRG'], dtype=object), 36)
# (array(['SDPGS'], dtype=object), 36)
# (array(['SDPGr'], dtype=object), 36)
# (array(['SDPGR'], dtype=object), 36)
# (array(['SDPGg'], dtype=object), 36)
# (array(['SDPGG'], dtype=object), 36)
# (array(['SDPGM'], dtype=object), 36)
# (array(['SDPGm'], dtype=object), 36)
# (array(['SDPGP'], dtype=object), 36)
# (array(['SDPGd'], dtype=object), 36)
# (array(['SDPGD'], dtype=object), 36)
# (array(['SDPGn'], dtype=object), 36)
# (array(['SDPGN'], dtype=object), 36)
# (array(['SDPMS'], dtype=object), 65)
# (array(['SDPMr'], dtype=object), 65)
# (array(['SDPMR'], dtype=object), 65)
# (array(['SDPMg'], dtype=object), 28)
# (array(['SDPMG'], dtype=object), 54)
# (array(['SDPMM'], dtype=object), 65)
# (array(['SDPMm'], dtype=object), 65)
# (array(['SDPMP'], dtype=object), 65)
# (array(['SDPMd'], dtype=object), 65)
# (array(['SDPMD'], dtype=object), 65)
# (array(['SDPMn'], dtype=object), 65)
# (array(['SDPMN'], dtype=object), 65)
# (array(['SDPmR'], dtype=object), 101)
# (array(['SDPmg'], dtype=object), 102)
# (array(['SDPmG'], dtype=object), 110)
# (array(['SDPmP'], dtype=object), 43)
# (array(['SDPDS'], dtype=object), 62)
# (array(['SDPDr'], dtype=object), 62)
# (array(['SDPDR'], dtype=object), 62)
# (array(['SDPDg'], dtype=object), 62)
# (array(['SDPDG'], dtype=object), 62)
# (array(['SDPDM'], dtype=object), 62)
# (array(['SDPDm'], dtype=object), 62)
# (array(['SDPDP'], dtype=object), 62)
# (array(['SDPDd'], dtype=object), 62)
# (array(['SDPDD'], dtype=object), 62)
# (array(['SDPDn'], dtype=object), 62)
# (array(['SDPDN'], dtype=object), 62)
# (array(['SnSgM'], dtype=object), 26)
# (array(['SnPMS'], dtype=object), 97)
# (array(['SnPMr'], dtype=object), 97)
# (array(['SnPMR'], dtype=object), 95)
# (array(['SnPMg'], dtype=object), 63)
# (array(['SnPMG'], dtype=object), 97)
# (array(['SnPMM'], dtype=object), 97)
# (array(['SnPMm'], dtype=object), 97)
# (array(['SnPMP'], dtype=object), 97)
# (array(['SnPMd'], dtype=object), 97)
# (array(['SnPMD'], dtype=object), 97)
# (array(['SnPMn'], dtype=object), 97)
# (array(['SnPMN'], dtype=object), 97)
# (array(['SnPnS'], dtype=object), 63)
# (array(['SnPNS'], dtype=object), 95)
# (array(['SndMS'], dtype=object), 86)
# (array(['SndMr'], dtype=object), 86)
# (array(['SndMR'], dtype=object), 86)
# (array(['SndMg'], dtype=object), 86)
# (array(['SndMG'], dtype=object), 86)
# (array(['SndMM'], dtype=object), 86)
# (array(['SndMm'], dtype=object), 86)
# (array(['SndMP'], dtype=object), 86)
# (array(['SndMd'], dtype=object), 86)
# (array(['SndMD'], dtype=object), 86)
# (array(['SndMn'], dtype=object), 86)
# (array(['SndMN'], dtype=object), 86)
# (array(['SndPS'], dtype=object), 14)
# (array(['SndPr'], dtype=object), 14)
# (array(['SndPR'], dtype=object), 14)
# (array(['SndPg'], dtype=object), 14)
# (array(['SndPG'], dtype=object), 14)
# (array(['SndPM'], dtype=object), 14)
# (array(['SndPm'], dtype=object), 14)
# (array(['SndPP'], dtype=object), 14)
# (array(['SndPd'], dtype=object), 14)
# (array(['SndPD'], dtype=object), 14)
# (array(['SndPn'], dtype=object), 14)
# (array(['SndPN'], dtype=object), 14)
# (array(['SndnS'], dtype=object), 87)
# (array(['SnDPS'], dtype=object), 24)
# (array(['SnDPr'], dtype=object), 24)
# (array(['SnDPR'], dtype=object), 24)
# (array(['SnDPg'], dtype=object), 24)
# (array(['SnDPG'], dtype=object), 24)
# (array(['SnDPM'], dtype=object), 23)
# (array(['SnDPm'], dtype=object), 101)
# (array(['SnDPP'], dtype=object), 24)
# (array(['SnDPd'], dtype=object), 73)
# (array(['SnDPD'], dtype=object), 4)
# (array(['SnDPn'], dtype=object), 15)
# (array(['SnDPN'], dtype=object), 51)
# (array(['SnDnS'], dtype=object), 6)
# (array(['SNSRM'], dtype=object), 51)
# (array(['SNSGM'], dtype=object), 41)
# (array(['SNrGm'], dtype=object), 93)
# (array(['SNRGm'], dtype=object), 106)
# (array(['SNPGS'], dtype=object), 72)
# (array(['SNPGr'], dtype=object), 72)
# (array(['SNPGR'], dtype=object), 72)
# (array(['SNPGg'], dtype=object), 72)
# (array(['SNPGG'], dtype=object), 72)
# (array(['SNPGM'], dtype=object), 72)
# (array(['SNPGm'], dtype=object), 72)
# (array(['SNPGP'], dtype=object), 72)
# (array(['SNPGd'], dtype=object), 72)
# (array(['SNPGD'], dtype=object), 72)
# (array(['SNPGn'], dtype=object), 72)
# (array(['SNPGN'], dtype=object), 72)
# (array(['SNPNS'], dtype=object), 72)
# (array(['SNdMS'], dtype=object), 45)
# (array(['SNdMr'], dtype=object), 45)
# (array(['SNdMR'], dtype=object), 45)
# (array(['SNdMg'], dtype=object), 45)
# (array(['SNdMG'], dtype=object), 45)
# (array(['SNdMM'], dtype=object), 45)
# (array(['SNdMm'], dtype=object), 45)
# (array(['SNdMP'], dtype=object), 45)
# (array(['SNdMd'], dtype=object), 45)
# (array(['SNdMD'], dtype=object), 45)
# (array(['SNdMn'], dtype=object), 45)
# (array(['SNdMN'], dtype=object), 45)
# (array(['SNdPS'], dtype=object), 11)
# (array(['SNdPr'], dtype=object), 11)
# (array(['SNdPR'], dtype=object), 11)
# (array(['SNdPg'], dtype=object), 11)
# (array(['SNdPG'], dtype=object), 11)
# (array(['SNdPM'], dtype=object), 11)
# (array(['SNdPm'], dtype=object), 11)
# (array(['SNdPP'], dtype=object), 11)
# (array(['SNdPd'], dtype=object), 11)
# (array(['SNdPD'], dtype=object), 11)
# (array(['SNdPn'], dtype=object), 11)
# (array(['SNdPN'], dtype=object), 11)
# (array(['SNdNS'], dtype=object), 46)
# (array(['SNDgM'], dtype=object), 7)
# (array(['SNDMS'], dtype=object), 7)
# (array(['SNDMr'], dtype=object), 7)
# (array(['SNDMR'], dtype=object), 7)
# (array(['SNDMg'], dtype=object), 7)
# (array(['SNDMG'], dtype=object), 7)
# (array(['SNDMM'], dtype=object), 7)
# (array(['SNDMm'], dtype=object), 7)
# (array(['SNDMP'], dtype=object), 7)
# (array(['SNDMd'], dtype=object), 7)
# (array(['SNDMD'], dtype=object), 7)
# (array(['SNDMn'], dtype=object), 7)
# (array(['SNDMN'], dtype=object), 7)
# (array(['SNDmS'], dtype=object), 90)
# (array(['SNDmr'], dtype=object), 90)
# (array(['SNDmR'], dtype=object), 90)
# (array(['SNDmg'], dtype=object), 90)
# (array(['SNDmG'], dtype=object), 90)
# (array(['SNDmM'], dtype=object), 90)
# (array(['SNDmm'], dtype=object), 90)
# (array(['SNDmP'], dtype=object), 90)
# (array(['SNDmd'], dtype=object), 90)
# (array(['SNDmD'], dtype=object), 90)
# (array(['SNDmn'], dtype=object), 90)
# (array(['SNDmN'], dtype=object), 90)
# (array(['SNDPS'], dtype=object), 111)
# (array(['SNDPr'], dtype=object), 111)
# (array(['SNDPR'], dtype=object), 106)
# (array(['SNDPg'], dtype=object), 111)
# (array(['SNDPG'], dtype=object), 41)
# (array(['SNDPM'], dtype=object), 84)
# (array(['SNDPm'], dtype=object), 111)
# (array(['SNDPP'], dtype=object), 111)
# (array(['SNDPd'], dtype=object), 102)
# (array(['SNDPD'], dtype=object), 92)
# (array(['SNDPn'], dtype=object), 111)
# (array(['SNDPN'], dtype=object), 41)
# (array(['SNDnS'], dtype=object), 7)
# (array(['SNDNS'], dtype=object), 114)
# (array(['rSrgM'], dtype=object), 14)
# (array(['rSrgm'], dtype=object), 102)
# (array(['rSrGM'], dtype=object), 1)
# (array(['rSRgM'], dtype=object), 50)
# (array(['rSRGR'], dtype=object), 36)
# (array(['rSRGP'], dtype=object), 39)
# (array(['rSRMP'], dtype=object), 61)
# (array(['rSRmP'], dtype=object), 101)
# (array(['rSgMP'], dtype=object), 26)
# (array(['rSgMd'], dtype=object), 88)
# (array(['rSgMD'], dtype=object), 7)
# (array(['rSGMP'], dtype=object), 41)
# (array(['rSMGP'], dtype=object), 84)
# (array(['rSdnP'], dtype=object), 47)
# (array(['rSDPG'], dtype=object), 36)
# (array(['rSDPM'], dtype=object), 65)
# (array(['rSDPD'], dtype=object), 62)
# (array(['rSnPM'], dtype=object), 97)
# (array(['rSndM'], dtype=object), 86)
# (array(['rSndP'], dtype=object), 14)
# (array(['rSnDP'], dtype=object), 0)
# (array(['rSNPG'], dtype=object), 72)
# (array(['rSNdM'], dtype=object), 45)
# (array(['rSNdP'], dtype=object), 11)
# (array(['rSNDM'], dtype=object), 7)
# (array(['rSNDm'], dtype=object), 90)
# (array(['rSNDP'], dtype=object), 94)
# (array(['rrgMP'], dtype=object), 14)
# (array(['rrgmP'], dtype=object), 102)
# (array(['rrGMP'], dtype=object), 1)
# (array(['rrGmD'], dtype=object), 93)
# (array(['rRSRG'], dtype=object), 36)
# (array(['rRgMP'], dtype=object), 50)
# (array(['rRGRS'], dtype=object), 36)
# (array(['rRGmD'], dtype=object), 106)
# (array(['rRGPD'], dtype=object), 37)
# (array(['rRGPN'], dtype=object), 72)
# (array(['rRGNS'], dtype=object), 51)
# (array(['rRMPd'], dtype=object), 73)
# (array(['rRMPD'], dtype=object), 69)
# (array(['rRMPN'], dtype=object), 59)
# (array(['rRmPD'], dtype=object), 101)
# (array(['rgMRS'], dtype=object), 47)
# (array(['rgMgr'], dtype=object), 14)
# (array(['rgMgR'], dtype=object), 7)
# (array(['rgMPS'], dtype=object), 14)
# (array(['rgMPr'], dtype=object), 14)
# (array(['rgMPR'], dtype=object), 14)
# (array(['rgMPg'], dtype=object), 14)
# (array(['rgMPG'], dtype=object), 14)
# (array(['rgMPM'], dtype=object), 14)
# (array(['rgMPm'], dtype=object), 14)
# (array(['rgMPP'], dtype=object), 14)
# (array(['rgMPd'], dtype=object), 14)
# (array(['rgMPD'], dtype=object), 83)
# (array(['rgMPn'], dtype=object), 27)
# (array(['rgMPN'], dtype=object), 14)
# (array(['rgMdn'], dtype=object), 86)
# (array(['rgMdN'], dtype=object), 45)
# (array(['rgMDn'], dtype=object), 7)
# (array(['rgmgr'], dtype=object), 102)
# (array(['rgmPS'], dtype=object), 102)
# (array(['rgmPr'], dtype=object), 102)
# (array(['rgmPR'], dtype=object), 102)
# (array(['rgmPg'], dtype=object), 102)
# (array(['rgmPG'], dtype=object), 102)
# (array(['rgmPM'], dtype=object), 102)
# (array(['rgmPm'], dtype=object), 102)
# (array(['rgmPP'], dtype=object), 102)
# (array(['rgmPd'], dtype=object), 102)
# (array(['rgmPD'], dtype=object), 102)
# (array(['rgmPn'], dtype=object), 102)
# (array(['rgmPN'], dtype=object), 102)
# (array(['rGRGS'], dtype=object), 80)
# (array(['rGRGN'], dtype=object), 51)
# (array(['rGMGr'], dtype=object), 1)
# (array(['rGMGR'], dtype=object), 41)
# (array(['rGMPS'], dtype=object), 1)
# (array(['rGMPr'], dtype=object), 1)
# (array(['rGMPR'], dtype=object), 1)
# (array(['rGMPg'], dtype=object), 1)
# (array(['rGMPG'], dtype=object), 1)
# (array(['rGMPM'], dtype=object), 1)
# (array(['rGMPm'], dtype=object), 1)
# (array(['rGMPP'], dtype=object), 1)
# (array(['rGMPd'], dtype=object), 11)
# (array(['rGMPD'], dtype=object), 0)
# (array(['rGMPn'], dtype=object), 1)
# (array(['rGMPN'], dtype=object), 3)
# (array(['rGmrS'], dtype=object), 91)
# (array(['rGmrG'], dtype=object), 91)
# (array(['rGmGr'], dtype=object), 93)
# (array(['rGmDS'], dtype=object), 93)
# (array(['rGmDr'], dtype=object), 93)
# (array(['rGmDR'], dtype=object), 93)
# (array(['rGmDg'], dtype=object), 93)
# (array(['rGmDG'], dtype=object), 93)
# (array(['rGmDM'], dtype=object), 93)
# (array(['rGmDm'], dtype=object), 90)
# (array(['rGmDP'], dtype=object), 91)
# (array(['rGmDd'], dtype=object), 93)
# (array(['rGmDD'], dtype=object), 93)
# (array(['rGmDn'], dtype=object), 93)
# (array(['rGmDN'], dtype=object), 93)
# (array(['rGPGR'], dtype=object), 62)
# (array(['rGPmP'], dtype=object), 84)
# (array(['rGPDS'], dtype=object), 37)
# (array(['rGPNS'], dtype=object), 72)
# (array(['rMgrS'], dtype=object), 14)
# (array(['rMgRS'], dtype=object), 19)
# (array(['rMGrS'], dtype=object), 1)
# (array(['rMGRS'], dtype=object), 41)
# (array(['rMGRG'], dtype=object), 56)
# (array(['rMGPm'], dtype=object), 84)
# (array(['rMPgM'], dtype=object), 47)
# (array(['rMPdn'], dtype=object), 78)
# (array(['rMPdN'], dtype=object), 11)
# (array(['rMPDS'], dtype=object), 69)
# (array(['rMPDg'], dtype=object), 7)
# (array(['rMPDn'], dtype=object), 6)
# (array(['rMPnS'], dtype=object), 26)
# (array(['rMPNS'], dtype=object), 60)
# (array(['rMdnS'], dtype=object), 86)
# (array(['rMdNS'], dtype=object), 45)
# (array(['rMDnS'], dtype=object), 7)
# (array(['rmgrS'], dtype=object), 102)
# (array(['rmGrS'], dtype=object), 93)
# (array(['rmGRS'], dtype=object), 106)
# (array(['rmPGM'], dtype=object), 41)
# (array(['rmPdN'], dtype=object), 102)
# (array(['rmPDS'], dtype=object), 101)
# (array(['rmPDP'], dtype=object), 84)
# (array(['rmPDN'], dtype=object), 84)
# (array(['rmDNS'], dtype=object), 115)
# (array(['rPRGR'], dtype=object), 36)
# (array(['rPRGm'], dtype=object), 106)
# (array(['rPgMR'], dtype=object), 47)
# (array(['rPGRS'], dtype=object), 39)
# (array(['rPGMG'], dtype=object), 41)
# (array(['rPMRS'], dtype=object), 100)
# (array(['rPMgS'], dtype=object), 63)
# (array(['rPMgr'], dtype=object), 14)
# (array(['rPMgR'], dtype=object), 29)
# (array(['rPMGr'], dtype=object), 1)
# (array(['rPMGR'], dtype=object), 56)
# (array(['rPMPg'], dtype=object), 47)
# (array(['rPmRS'], dtype=object), 101)
# (array(['rPmgr'], dtype=object), 102)
# (array(['rPmGr'], dtype=object), 91)
# (array(['rPmGR'], dtype=object), 106)
# (array(['rPmPG'], dtype=object), 41)
# (array(['rPmPD'], dtype=object), 84)
# (array(['rPdnS'], dtype=object), 78)
# (array(['rPdNS'], dtype=object), 103)
# (array(['rPDgM'], dtype=object), 7)
# (array(['rPDGP'], dtype=object), 62)
# (array(['rPDPM'], dtype=object), 84)
# (array(['rPDnS'], dtype=object), 6)
# (array(['rPDNS'], dtype=object), 84)
# (array(['rPnSg'], dtype=object), 63)
# (array(['rdMgS'], dtype=object), 88)
# (array(['rdPMg'], dtype=object), 14)
# (array(['rdPMG'], dtype=object), 11)
# (array(['rdnPM'], dtype=object), 47)
# (array(['rDRSR'], dtype=object), 36)
# (array(['rDgMg'], dtype=object), 7)
# (array(['rDGPG'], dtype=object), 62)
# (array(['rDMPD'], dtype=object), 7)
# (array(['rDmGr'], dtype=object), 90)
# (array(['rDPGR'], dtype=object), 36)
# (array(['rDPMR'], dtype=object), 71)
# (array(['rDPMg'], dtype=object), 29)
# (array(['rDPMG'], dtype=object), 52)
# (array(['rDPmR'], dtype=object), 101)
# (array(['rDPmg'], dtype=object), 102)
# (array(['rDPmG'], dtype=object), 110)
# (array(['rDPmP'], dtype=object), 43)
# (array(['rDPDG'], dtype=object), 62)
# (array(['rnSgM'], dtype=object), 26)
# (array(['rnPMR'], dtype=object), 95)
# (array(['rnPMg'], dtype=object), 63)
# (array(['rnPMP'], dtype=object), 47)
# (array(['rndMg'], dtype=object), 86)
# (array(['rndPM'], dtype=object), 14)
# (array(['rnDPM'], dtype=object), 23)
# (array(['rnDPm'], dtype=object), 101)
# (array(['rNSRM'], dtype=object), 51)
# (array(['rNSGM'], dtype=object), 41)
# (array(['rNrGm'], dtype=object), 93)
# (array(['rNRGm'], dtype=object), 106)
# (array(['rNPGR'], dtype=object), 72)
# (array(['rNdMg'], dtype=object), 45)
# (array(['rNdPM'], dtype=object), 11)
# (array(['rNDMP'], dtype=object), 7)
# (array(['rNDmG'], dtype=object), 90)
# (array(['rNDPm'], dtype=object), 111)
# (array(['RSrgM'], dtype=object), 14)
# (array(['RSrgm'], dtype=object), 102)
# (array(['RSrGM'], dtype=object), 1)
# (array(['RSRSR'], dtype=object), 36)
# (array(['RSRgM'], dtype=object), 50)
# (array(['RSRGS'], dtype=object), 36)
# (array(['RSRGr'], dtype=object), 36)
# (array(['RSRGR'], dtype=object), 36)
# (array(['RSRGg'], dtype=object), 36)
# (array(['RSRGG'], dtype=object), 36)
# (array(['RSRGM'], dtype=object), 36)
# (array(['RSRGm'], dtype=object), 36)
# (array(['RSRGP'], dtype=object), 36)
# (array(['RSRGd'], dtype=object), 36)
# (array(['RSRGD'], dtype=object), 36)
# (array(['RSRGn'], dtype=object), 36)
# (array(['RSRGN'], dtype=object), 36)
# (array(['RSRMP'], dtype=object), 99)
# (array(['RSRmP'], dtype=object), 101)
# (array(['RSgMg'], dtype=object), 7)
# (array(['RSgMP'], dtype=object), 15)
# (array(['RSgMd'], dtype=object), 88)
# (array(['RSgMD'], dtype=object), 7)
# (array(['RSGMG'], dtype=object), 41)
# (array(['RSGMP'], dtype=object), 41)
# (array(['RSMGP'], dtype=object), 84)
# (array(['RSdnS'], dtype=object), 47)
# (array(['RSdnP'], dtype=object), 47)
# (array(['RSDPG'], dtype=object), 36)
# (array(['RSDPM'], dtype=object), 65)
# (array(['RSDPD'], dtype=object), 62)
# (array(['RSnPM'], dtype=object), 95)
# (array(['RSndM'], dtype=object), 86)
# (array(['RSndP'], dtype=object), 14)
# (array(['RSnDP'], dtype=object), 32)
# (array(['RSNPG'], dtype=object), 72)
# (array(['RSNdM'], dtype=object), 45)
# (array(['RSNdP'], dtype=object), 11)
# (array(['RSNDM'], dtype=object), 7)
# (array(['RSNDm'], dtype=object), 90)
# (array(['RSNDP'], dtype=object), 109)
# (array(['RrgMP'], dtype=object), 14)
# (array(['RrgmP'], dtype=object), 102)
# (array(['RrGMP'], dtype=object), 1)
# (array(['RrGmD'], dtype=object), 93)
# (array(['RRSRG'], dtype=object), 36)
# (array(['RRgMP'], dtype=object), 50)
# (array(['RRGRS'], dtype=object), 36)
# (array(['RRGmD'], dtype=object), 106)
# (array(['RRGPD'], dtype=object), 37)
# (array(['RRGPN'], dtype=object), 72)
# (array(['RRGNS'], dtype=object), 51)
# (array(['RRMPd'], dtype=object), 73)
# (array(['RRMPD'], dtype=object), 69)
# (array(['RRMPN'], dtype=object), 59)
# (array(['RRmPD'], dtype=object), 101)
# (array(['RgMRS'], dtype=object), 47)
# (array(['RgMRg'], dtype=object), 47)
# (array(['RgMgR'], dtype=object), 10)
# (array(['RgMPS'], dtype=object), 50)
# (array(['RgMPr'], dtype=object), 50)
# (array(['RgMPR'], dtype=object), 50)
# (array(['RgMPg'], dtype=object), 47)
# (array(['RgMPG'], dtype=object), 50)
# (array(['RgMPM'], dtype=object), 50)
# (array(['RgMPm'], dtype=object), 50)
# (array(['RgMPP'], dtype=object), 50)
# (array(['RgMPd'], dtype=object), 47)
# (array(['RgMPD'], dtype=object), 82)
# (array(['RgMPn'], dtype=object), 22)
# (array(['RgMPN'], dtype=object), 50)
# (array(['RgMdn'], dtype=object), 86)
# (array(['RgMdN'], dtype=object), 45)
# (array(['RgMDn'], dtype=object), 7)
# (array(['RgmPd'], dtype=object), 102)
# (array(['RGSRM'], dtype=object), 80)
# (array(['RGSnD'], dtype=object), 80)
# (array(['RGRSS'], dtype=object), 36)
# (array(['RGRSr'], dtype=object), 36)
# (array(['RGRSR'], dtype=object), 36)
# (array(['RGRSg'], dtype=object), 36)
# (array(['RGRSG'], dtype=object), 36)
# (array(['RGRSM'], dtype=object), 36)
# (array(['RGRSm'], dtype=object), 36)
# (array(['RGRSP'], dtype=object), 36)
# (array(['RGRSd'], dtype=object), 36)
# (array(['RGRSD'], dtype=object), 36)
# (array(['RGRSn'], dtype=object), 36)
# (array(['RGRSN'], dtype=object), 36)
# (array(['RGRGS'], dtype=object), 80)
# (array(['RGRGR'], dtype=object), 36)
# (array(['RGRGP'], dtype=object), 36)
# (array(['RGRGN'], dtype=object), 51)
# (array(['RGMGR'], dtype=object), 41)
# (array(['RGMPd'], dtype=object), 11)
# (array(['RGMPD'], dtype=object), 0)
# (array(['RGMPN'], dtype=object), 41)
# (array(['RGmrG'], dtype=object), 91)
# (array(['RGmGR'], dtype=object), 106)
# (array(['RGmDS'], dtype=object), 106)
# (array(['RGmDr'], dtype=object), 106)
# (array(['RGmDR'], dtype=object), 106)
# (array(['RGmDg'], dtype=object), 106)
# (array(['RGmDG'], dtype=object), 106)
# (array(['RGmDM'], dtype=object), 106)
# (array(['RGmDm'], dtype=object), 106)
# (array(['RGmDP'], dtype=object), 106)
# (array(['RGmDd'], dtype=object), 106)
# (array(['RGmDD'], dtype=object), 106)
# (array(['RGmDn'], dtype=object), 106)
# (array(['RGmDN'], dtype=object), 106)
# (array(['RGPRG'], dtype=object), 36)
# (array(['RGPGR'], dtype=object), 62)
# (array(['RGPGP'], dtype=object), 62)
# (array(['RGPmP'], dtype=object), 84)
# (array(['RGPDS'], dtype=object), 37)
# (array(['RGPDr'], dtype=object), 37)
# (array(['RGPDR'], dtype=object), 36)
# (array(['RGPDg'], dtype=object), 37)
# (array(['RGPDG'], dtype=object), 62)
# (array(['RGPDM'], dtype=object), 37)
# (array(['RGPDm'], dtype=object), 37)
# (array(['RGPDP'], dtype=object), 37)
# (array(['RGPDd'], dtype=object), 37)
# (array(['RGPDD'], dtype=object), 37)
# (array(['RGPDn'], dtype=object), 37)
# (array(['RGPDN'], dtype=object), 37)
# (array(['RGPNS'], dtype=object), 72)
# (array(['RGPNr'], dtype=object), 72)
# (array(['RGPNR'], dtype=object), 72)
# (array(['RGPNg'], dtype=object), 72)
# (array(['RGPNG'], dtype=object), 72)
# (array(['RGPNM'], dtype=object), 72)
# (array(['RGPNm'], dtype=object), 72)
# (array(['RGPNP'], dtype=object), 72)
# (array(['RGPNd'], dtype=object), 72)
# (array(['RGPND'], dtype=object), 72)
# (array(['RGPNn'], dtype=object), 72)
# (array(['RGPNN'], dtype=object), 72)
# (array(['RGNSS'], dtype=object), 51)
# (array(['RGNSr'], dtype=object), 51)
# (array(['RGNSR'], dtype=object), 51)
# (array(['RGNSg'], dtype=object), 51)
# (array(['RGNSG'], dtype=object), 51)
# (array(['RGNSM'], dtype=object), 51)
# (array(['RGNSm'], dtype=object), 51)
# (array(['RGNSP'], dtype=object), 51)
# (array(['RGNSd'], dtype=object), 51)
# (array(['RGNSD'], dtype=object), 51)
# (array(['RGNSn'], dtype=object), 51)
# (array(['RGNSN'], dtype=object), 51)
# (array(['RMgrS'], dtype=object), 14)
# (array(['RMgRS'], dtype=object), 73)
# (array(['RMGrS'], dtype=object), 1)
# (array(['RMGRS'], dtype=object), 41)
# (array(['RMGRG'], dtype=object), 56)
# (array(['RMGPm'], dtype=object), 84)
# (array(['RMPgM'], dtype=object), 47)
# (array(['RMPMR'], dtype=object), 98)
# (array(['RMPMg'], dtype=object), 73)
# (array(['RMPMG'], dtype=object), 56)
# (array(['RMPdS'], dtype=object), 73)
# (array(['RMPdr'], dtype=object), 73)
# (array(['RMPdR'], dtype=object), 73)
# (array(['RMPdg'], dtype=object), 73)
# (array(['RMPdG'], dtype=object), 73)
# (array(['RMPdM'], dtype=object), 73)
# (array(['RMPdm'], dtype=object), 73)
# (array(['RMPdP'], dtype=object), 73)
# (array(['RMPdd'], dtype=object), 73)
# (array(['RMPdD'], dtype=object), 73)
# (array(['RMPdn'], dtype=object), 73)
# (array(['RMPdN'], dtype=object), 74)
# (array(['RMPDS'], dtype=object), 69)
# (array(['RMPDr'], dtype=object), 69)
# (array(['RMPDR'], dtype=object), 69)
# (array(['RMPDg'], dtype=object), 9)
# (array(['RMPDG'], dtype=object), 69)
# (array(['RMPDM'], dtype=object), 69)
# (array(['RMPDm'], dtype=object), 69)
# (array(['RMPDP'], dtype=object), 69)
# (array(['RMPDd'], dtype=object), 69)
# (array(['RMPDD'], dtype=object), 69)
# (array(['RMPDn'], dtype=object), 67)
# (array(['RMPDN'], dtype=object), 69)
# (array(['RMPnS'], dtype=object), 26)
# (array(['RMPNS'], dtype=object), 59)
# (array(['RMPNr'], dtype=object), 59)
# (array(['RMPNR'], dtype=object), 59)
# (array(['RMPNg'], dtype=object), 59)
# (array(['RMPNG'], dtype=object), 59)
# (array(['RMPNM'], dtype=object), 59)
# (array(['RMPNm'], dtype=object), 59)
# (array(['RMPNP'], dtype=object), 59)
# (array(['RMPNd'], dtype=object), 59)
# (array(['RMPND'], dtype=object), 59)
# (array(['RMPNn'], dtype=object), 59)
# (array(['RMPNN'], dtype=object), 59)
# (array(['RMdnS'], dtype=object), 86)
# (array(['RMdNS'], dtype=object), 45)
# (array(['RMDnS'], dtype=object), 7)
# (array(['RmgrS'], dtype=object), 102)
# (array(['RmGrS'], dtype=object), 93)
# (array(['RmGRS'], dtype=object), 106)
# (array(['RmPGM'], dtype=object), 41)
# (array(['RmPmR'], dtype=object), 101)
# (array(['RmPdN'], dtype=object), 102)
# (array(['RmPDS'], dtype=object), 101)
# (array(['RmPDr'], dtype=object), 101)
# (array(['RmPDR'], dtype=object), 101)
# (array(['RmPDg'], dtype=object), 101)
# (array(['RmPDG'], dtype=object), 101)
# (array(['RmPDM'], dtype=object), 101)
# (array(['RmPDm'], dtype=object), 101)
# (array(['RmPDP'], dtype=object), 101)
# (array(['RmPDd'], dtype=object), 101)
# (array(['RmPDD'], dtype=object), 101)
# (array(['RmPDn'], dtype=object), 101)
# (array(['RmPDN'], dtype=object), 85)
# (array(['RmDNS'], dtype=object), 115)
# (array(['RPRGR'], dtype=object), 36)
# (array(['RPRGm'], dtype=object), 106)
# (array(['RPgMR'], dtype=object), 47)
# (array(['RPGRS'], dtype=object), 39)
# (array(['RPGMG'], dtype=object), 41)
# (array(['RPMRS'], dtype=object), 100)
# (array(['RPMgS'], dtype=object), 63)
# (array(['RPMgr'], dtype=object), 14)
# (array(['RPMgR'], dtype=object), 29)
# (array(['RPMGr'], dtype=object), 1)
# (array(['RPMGR'], dtype=object), 56)
# (array(['RPMPg'], dtype=object), 47)
# (array(['RPmRS'], dtype=object), 101)
# (array(['RPmgr'], dtype=object), 102)
# (array(['RPmGr'], dtype=object), 91)
# (array(['RPmGR'], dtype=object), 106)
# (array(['RPmPG'], dtype=object), 41)
# (array(['RPmPD'], dtype=object), 84)
# (array(['RPdnS'], dtype=object), 78)
# (array(['RPdNS'], dtype=object), 103)
# (array(['RPDgM'], dtype=object), 7)
# (array(['RPDGP'], dtype=object), 62)
# (array(['RPDPM'], dtype=object), 84)
# (array(['RPDnS'], dtype=object), 6)
# (array(['RPDNS'], dtype=object), 84)
# (array(['RPnSg'], dtype=object), 63)
# (array(['RdMgS'], dtype=object), 88)
# (array(['RdPMg'], dtype=object), 14)
# (array(['RdPMG'], dtype=object), 11)
# (array(['RdnPM'], dtype=object), 47)
# (array(['RDRSR'], dtype=object), 36)
# (array(['RDgMg'], dtype=object), 7)
# (array(['RDGPG'], dtype=object), 62)
# (array(['RDMPD'], dtype=object), 7)
# (array(['RDmGr'], dtype=object), 90)
# (array(['RDPGR'], dtype=object), 36)
# (array(['RDPMR'], dtype=object), 71)
# (array(['RDPMg'], dtype=object), 29)
# (array(['RDPMG'], dtype=object), 52)
# (array(['RDPmR'], dtype=object), 101)
# (array(['RDPmg'], dtype=object), 102)
# (array(['RDPmG'], dtype=object), 110)
# (array(['RDPmP'], dtype=object), 43)
# (array(['RDPDG'], dtype=object), 62)
# (array(['RnSgM'], dtype=object), 26)
# (array(['RnPMR'], dtype=object), 95)
# (array(['RnPMg'], dtype=object), 63)
# (array(['RnPMP'], dtype=object), 47)
# (array(['RndMg'], dtype=object), 86)
# (array(['RndPM'], dtype=object), 14)
# (array(['RnDPM'], dtype=object), 23)
# (array(['RnDPm'], dtype=object), 101)
# (array(['RNSRM'], dtype=object), 51)
# (array(['RNSGM'], dtype=object), 41)
# (array(['RNrGm'], dtype=object), 93)
# (array(['RNRGm'], dtype=object), 106)
# (array(['RNPGR'], dtype=object), 72)
# (array(['RNdMg'], dtype=object), 45)
# (array(['RNdPM'], dtype=object), 11)
# (array(['RNDMP'], dtype=object), 7)
# (array(['RNDmG'], dtype=object), 90)
# (array(['RNDPm'], dtype=object), 111)
# (array(['gSrgM'], dtype=object), 14)
# (array(['gSrgm'], dtype=object), 102)
# (array(['gSrGM'], dtype=object), 1)
# (array(['gSRgM'], dtype=object), 50)
# (array(['gSRGR'], dtype=object), 36)
# (array(['gSRGP'], dtype=object), 39)
# (array(['gSRMP'], dtype=object), 61)
# (array(['gSRmP'], dtype=object), 101)
# (array(['gSgMP'], dtype=object), 63)
# (array(['gSgMd'], dtype=object), 88)
# (array(['gSgMD'], dtype=object), 7)
# (array(['gSGMP'], dtype=object), 41)
# (array(['gSMGP'], dtype=object), 84)
# (array(['gSdnP'], dtype=object), 47)
# (array(['gSDPG'], dtype=object), 36)
# (array(['gSDPM'], dtype=object), 65)
# (array(['gSDPD'], dtype=object), 62)
# (array(['gSnPM'], dtype=object), 63)
# (array(['gSndM'], dtype=object), 86)
# (array(['gSndP'], dtype=object), 14)
# (array(['gSnDP'], dtype=object), 24)
# (array(['gSNPG'], dtype=object), 72)
# (array(['gSNdM'], dtype=object), 45)
# (array(['gSNdP'], dtype=object), 11)
# (array(['gSNDM'], dtype=object), 7)
# (array(['gSNDm'], dtype=object), 90)
# (array(['gSNDP'], dtype=object), 111)
# (array(['grSrg'], dtype=object), 104)
# (array(['grSnd'], dtype=object), 14)
# (array(['grSND'], dtype=object), 102)
# (array(['grgMP'], dtype=object), 14)
# (array(['grgmP'], dtype=object), 102)
# (array(['grGMP'], dtype=object), 1)
# (array(['grGmD'], dtype=object), 93)
# (array(['gRSRg'], dtype=object), 82)
# (array(['gRSRG'], dtype=object), 36)
# (array(['gRSRM'], dtype=object), 73)
# (array(['gRSgM'], dtype=object), 17)
# (array(['gRSnD'], dtype=object), 29)
# (array(['gRSND'], dtype=object), 7)
# (array(['gRgMP'], dtype=object), 82)
# (array(['gRGRS'], dtype=object), 36)
# (array(['gRGmD'], dtype=object), 106)
# (array(['gRGPD'], dtype=object), 37)
# (array(['gRGPN'], dtype=object), 72)
# (array(['gRGNS'], dtype=object), 51)
# (array(['gRMPd'], dtype=object), 73)
# (array(['gRMPD'], dtype=object), 69)
# (array(['gRMPN'], dtype=object), 59)
# (array(['gRmPD'], dtype=object), 101)
# (array(['ggMRS'], dtype=object), 47)
# (array(['ggMgR'], dtype=object), 7)
# (array(['ggMPd'], dtype=object), 48)
# (array(['ggMPD'], dtype=object), 82)
# (array(['ggMPn'], dtype=object), 26)
# (array(['ggMdn'], dtype=object), 86)
# (array(['ggMdN'], dtype=object), 45)
# (array(['ggMDn'], dtype=object), 7)
# (array(['ggmPd'], dtype=object), 102)
# (array(['gGRGS'], dtype=object), 80)
# (array(['gGRGN'], dtype=object), 51)
# (array(['gGMGR'], dtype=object), 41)
# (array(['gGMPd'], dtype=object), 11)
# (array(['gGMPD'], dtype=object), 0)
# (array(['gGMPN'], dtype=object), 41)
# (array(['gGmrG'], dtype=object), 91)
# (array(['gGmDN'], dtype=object), 115)
# (array(['gGPGR'], dtype=object), 62)
# (array(['gGPmP'], dtype=object), 84)
# (array(['gGPDS'], dtype=object), 37)
# (array(['gGPNS'], dtype=object), 72)
# (array(['gMRSS'], dtype=object), 47)
# (array(['gMRSr'], dtype=object), 47)
# (array(['gMRSR'], dtype=object), 47)
# (array(['gMRSg'], dtype=object), 47)
# (array(['gMRSG'], dtype=object), 47)
# (array(['gMRSM'], dtype=object), 47)
# (array(['gMRSm'], dtype=object), 47)
# (array(['gMRSP'], dtype=object), 47)
# (array(['gMRSd'], dtype=object), 47)
# (array(['gMRSD'], dtype=object), 47)
# (array(['gMRSn'], dtype=object), 47)
# (array(['gMRSN'], dtype=object), 47)
# (array(['gMRgM'], dtype=object), 47)
# (array(['gMgrS'], dtype=object), 14)
# (array(['gMgRS'], dtype=object), 7)
# (array(['gMgRr'], dtype=object), 7)
# (array(['gMgRR'], dtype=object), 7)
# (array(['gMgRg'], dtype=object), 7)
# (array(['gMgRG'], dtype=object), 7)
# (array(['gMgRM'], dtype=object), 7)
# (array(['gMgRm'], dtype=object), 7)
# (array(['gMgRP'], dtype=object), 7)
# (array(['gMgRd'], dtype=object), 7)
# (array(['gMgRD'], dtype=object), 7)
# (array(['gMgRn'], dtype=object), 7)
# (array(['gMgRN'], dtype=object), 7)
# (array(['gMgMg'], dtype=object), 7)
# (array(['gMgMD'], dtype=object), 7)
# (array(['gMGrS'], dtype=object), 1)
# (array(['gMGRS'], dtype=object), 41)
# (array(['gMGRG'], dtype=object), 56)
# (array(['gMGPm'], dtype=object), 84)
# (array(['gMPgM'], dtype=object), 47)
# (array(['gMPMg'], dtype=object), 34)
# (array(['gMPMP'], dtype=object), 47)
# (array(['gMPdS'], dtype=object), 48)
# (array(['gMPdr'], dtype=object), 48)
# (array(['gMPdR'], dtype=object), 48)
# (array(['gMPdg'], dtype=object), 48)
# (array(['gMPdG'], dtype=object), 48)
# (array(['gMPdM'], dtype=object), 48)
# (array(['gMPdm'], dtype=object), 48)
# (array(['gMPdP'], dtype=object), 14)
# (array(['gMPdd'], dtype=object), 48)
# (array(['gMPdD'], dtype=object), 48)
# (array(['gMPdn'], dtype=object), 48)
# (array(['gMPdN'], dtype=object), 13)
# (array(['gMPDS'], dtype=object), 70)
# (array(['gMPDr'], dtype=object), 82)
# (array(['gMPDR'], dtype=object), 82)
# (array(['gMPDg'], dtype=object), 7)
# (array(['gMPDG'], dtype=object), 82)
# (array(['gMPDM'], dtype=object), 82)
# (array(['gMPDm'], dtype=object), 82)
# (array(['gMPDP'], dtype=object), 82)
# (array(['gMPDd'], dtype=object), 82)
# (array(['gMPDD'], dtype=object), 82)
# (array(['gMPDn'], dtype=object), 82)
# (array(['gMPDN'], dtype=object), 82)
# (array(['gMPnS'], dtype=object), 26)
# (array(['gMPnr'], dtype=object), 26)
# (array(['gMPnR'], dtype=object), 26)
# (array(['gMPng'], dtype=object), 26)
# (array(['gMPnG'], dtype=object), 26)
# (array(['gMPnM'], dtype=object), 26)
# (array(['gMPnm'], dtype=object), 26)
# (array(['gMPnP'], dtype=object), 63)
# (array(['gMPnd'], dtype=object), 26)
# (array(['gMPnD'], dtype=object), 15)
# (array(['gMPnn'], dtype=object), 26)
# (array(['gMPnN'], dtype=object), 26)
# (array(['gMPNS'], dtype=object), 60)
# (array(['gMdMg'], dtype=object), 88)
# (array(['gMdnS'], dtype=object), 86)
# (array(['gMdnr'], dtype=object), 86)
# (array(['gMdnR'], dtype=object), 86)
# (array(['gMdng'], dtype=object), 86)
# (array(['gMdnG'], dtype=object), 86)
# (array(['gMdnM'], dtype=object), 86)
# (array(['gMdnm'], dtype=object), 86)
# (array(['gMdnP'], dtype=object), 86)
# (array(['gMdnd'], dtype=object), 86)
# (array(['gMdnD'], dtype=object), 86)
# (array(['gMdnn'], dtype=object), 86)
# (array(['gMdnN'], dtype=object), 86)
# (array(['gMdNS'], dtype=object), 45)
# (array(['gMdNr'], dtype=object), 45)
# (array(['gMdNR'], dtype=object), 45)
# (array(['gMdNg'], dtype=object), 45)
# (array(['gMdNG'], dtype=object), 45)
# (array(['gMdNM'], dtype=object), 45)
# (array(['gMdNm'], dtype=object), 45)
# (array(['gMdNP'], dtype=object), 45)
# (array(['gMdNd'], dtype=object), 45)
# (array(['gMdND'], dtype=object), 45)
# (array(['gMdNn'], dtype=object), 45)
# (array(['gMdNN'], dtype=object), 45)
# (array(['gMDgM'], dtype=object), 7)
# (array(['gMDMP'], dtype=object), 7)
# (array(['gMDnS'], dtype=object), 7)
# (array(['gMDnr'], dtype=object), 7)
# (array(['gMDnR'], dtype=object), 7)
# (array(['gMDng'], dtype=object), 7)
# (array(['gMDnG'], dtype=object), 7)
# (array(['gMDnM'], dtype=object), 7)
# (array(['gMDnm'], dtype=object), 7)
# (array(['gMDnP'], dtype=object), 7)
# (array(['gMDnd'], dtype=object), 7)
# (array(['gMDnD'], dtype=object), 7)
# (array(['gMDnn'], dtype=object), 7)
# (array(['gMDnN'], dtype=object), 7)
# (array(['gmgrS'], dtype=object), 102)
# (array(['gmGrS'], dtype=object), 93)
# (array(['gmGRS'], dtype=object), 106)
# (array(['gmPGM'], dtype=object), 41)
# (array(['gmPmg'], dtype=object), 102)
# (array(['gmPdS'], dtype=object), 102)
# (array(['gmPdr'], dtype=object), 102)
# (array(['gmPdR'], dtype=object), 102)
# (array(['gmPdg'], dtype=object), 102)
# (array(['gmPdG'], dtype=object), 102)
# (array(['gmPdM'], dtype=object), 102)
# (array(['gmPdm'], dtype=object), 102)
# (array(['gmPdP'], dtype=object), 102)
# (array(['gmPdd'], dtype=object), 102)
# (array(['gmPdD'], dtype=object), 102)
# (array(['gmPdn'], dtype=object), 102)
# (array(['gmPdN'], dtype=object), 102)
# (array(['gmPDS'], dtype=object), 101)
# (array(['gmPDP'], dtype=object), 84)
# (array(['gmPDN'], dtype=object), 84)
# (array(['gmDNS'], dtype=object), 115)
# (array(['gPRGR'], dtype=object), 36)
# (array(['gPRGm'], dtype=object), 106)
# (array(['gPgMR'], dtype=object), 47)
# (array(['gPGRS'], dtype=object), 39)
# (array(['gPGMG'], dtype=object), 41)
# (array(['gPMRS'], dtype=object), 100)
# (array(['gPMgS'], dtype=object), 63)
# (array(['gPMgr'], dtype=object), 14)
# (array(['gPMgR'], dtype=object), 29)
# (array(['gPMGr'], dtype=object), 1)
# (array(['gPMGR'], dtype=object), 56)
# (array(['gPMPg'], dtype=object), 47)
# (array(['gPmRS'], dtype=object), 101)
# (array(['gPmgr'], dtype=object), 102)
# (array(['gPmGr'], dtype=object), 91)
# (array(['gPmGR'], dtype=object), 106)
# (array(['gPmPG'], dtype=object), 41)
# (array(['gPmPD'], dtype=object), 84)
# (array(['gPdnS'], dtype=object), 78)
# (array(['gPdNS'], dtype=object), 103)
# (array(['gPDgM'], dtype=object), 7)
# (array(['gPDGP'], dtype=object), 62)
# (array(['gPDPM'], dtype=object), 84)
# (array(['gPDnS'], dtype=object), 6)
# (array(['gPDNS'], dtype=object), 84)
# (array(['gPnSg'], dtype=object), 63)
# (array(['gdMgS'], dtype=object), 88)
# (array(['gdPMg'], dtype=object), 14)
# (array(['gdPMG'], dtype=object), 11)
# (array(['gdnPM'], dtype=object), 47)
# (array(['gDRSR'], dtype=object), 36)
# (array(['gDgMg'], dtype=object), 7)
# (array(['gDGPG'], dtype=object), 62)
# (array(['gDMPD'], dtype=object), 7)
# (array(['gDmGr'], dtype=object), 90)
# (array(['gDPGR'], dtype=object), 36)
# (array(['gDPMR'], dtype=object), 71)
# (array(['gDPMg'], dtype=object), 29)
# (array(['gDPMG'], dtype=object), 52)
# (array(['gDPmR'], dtype=object), 101)
# (array(['gDPmg'], dtype=object), 102)
# (array(['gDPmG'], dtype=object), 110)
# (array(['gDPmP'], dtype=object), 43)
# (array(['gDPDG'], dtype=object), 62)
# (array(['gnSgM'], dtype=object), 26)
# (array(['gnPMR'], dtype=object), 95)
# (array(['gnPMg'], dtype=object), 63)
# (array(['gnPMP'], dtype=object), 47)
# (array(['gndMg'], dtype=object), 86)
# (array(['gndPM'], dtype=object), 14)
# (array(['gnDPM'], dtype=object), 23)
# (array(['gnDPm'], dtype=object), 101)
# (array(['gNSRM'], dtype=object), 51)
# (array(['gNSGM'], dtype=object), 41)
# (array(['gNrGm'], dtype=object), 93)
# (array(['gNRGm'], dtype=object), 106)
# (array(['gNPGR'], dtype=object), 72)
# (array(['gNdMg'], dtype=object), 45)
# (array(['gNdPM'], dtype=object), 11)
# (array(['gNDMP'], dtype=object), 7)
# (array(['gNDmG'], dtype=object), 90)
# (array(['gNDPm'], dtype=object), 111)
# (array(['GSrgM'], dtype=object), 14)
# (array(['GSrgm'], dtype=object), 102)
# (array(['GSrGM'], dtype=object), 1)
# (array(['GSRgM'], dtype=object), 50)
# (array(['GSRGR'], dtype=object), 36)
# (array(['GSRGP'], dtype=object), 39)
# (array(['GSRMP'], dtype=object), 80)
# (array(['GSRmP'], dtype=object), 101)
# (array(['GSgMP'], dtype=object), 26)
# (array(['GSgMd'], dtype=object), 88)
# (array(['GSgMD'], dtype=object), 7)
# (array(['GSGMP'], dtype=object), 41)
# (array(['GSMGP'], dtype=object), 84)
# (array(['GSdnP'], dtype=object), 47)
# (array(['GSDPG'], dtype=object), 36)
# (array(['GSDPM'], dtype=object), 65)
# (array(['GSDPD'], dtype=object), 62)
# (array(['GSnPM'], dtype=object), 97)
# (array(['GSndM'], dtype=object), 86)
# (array(['GSndP'], dtype=object), 14)
# (array(['GSnDP'], dtype=object), 80)
# (array(['GSNPG'], dtype=object), 72)
# (array(['GSNdM'], dtype=object), 45)
# (array(['GSNdP'], dtype=object), 11)
# (array(['GSNDM'], dtype=object), 7)
# (array(['GSNDm'], dtype=object), 90)
# (array(['GSNDP'], dtype=object), 111)
# (array(['GrSrG'], dtype=object), 1)
# (array(['GrSnD'], dtype=object), 0)
# (array(['GrSNd'], dtype=object), 11)
# (array(['GrSND'], dtype=object), 93)
# (array(['GrgMP'], dtype=object), 14)
# (array(['GrgmP'], dtype=object), 102)
# (array(['GrGMP'], dtype=object), 1)
# (array(['GrGmr'], dtype=object), 91)
# (array(['GrGmD'], dtype=object), 93)
# (array(['GRSRS'], dtype=object), 36)
# (array(['GRSRG'], dtype=object), 36)
# (array(['GRSGM'], dtype=object), 41)
# (array(['GRSDP'], dtype=object), 37)
# (array(['GRSNP'], dtype=object), 72)
# (array(['GRSND'], dtype=object), 108)
# (array(['GRgMP'], dtype=object), 50)
# (array(['GRGSS'], dtype=object), 80)
# (array(['GRGSr'], dtype=object), 80)
# (array(['GRGSR'], dtype=object), 80)
# (array(['GRGSg'], dtype=object), 80)
# (array(['GRGSG'], dtype=object), 80)
# (array(['GRGSM'], dtype=object), 80)
# (array(['GRGSm'], dtype=object), 80)
# (array(['GRGSP'], dtype=object), 80)
# (array(['GRGSd'], dtype=object), 80)
# (array(['GRGSD'], dtype=object), 80)
# (array(['GRGSn'], dtype=object), 80)
# (array(['GRGSN'], dtype=object), 80)
# (array(['GRGRS'], dtype=object), 36)
# (array(['GRGRG'], dtype=object), 56)
# (array(['GRGmD'], dtype=object), 106)
# (array(['GRGPG'], dtype=object), 62)
# (array(['GRGPD'], dtype=object), 37)
# (array(['GRGPN'], dtype=object), 72)
# (array(['GRGNS'], dtype=object), 51)
# (array(['GRGNr'], dtype=object), 51)
# (array(['GRGNR'], dtype=object), 51)
# (array(['GRGNg'], dtype=object), 51)
# (array(['GRGNG'], dtype=object), 51)
# (array(['GRGNM'], dtype=object), 51)
# (array(['GRGNm'], dtype=object), 51)
# (array(['GRGNP'], dtype=object), 51)
# (array(['GRGNd'], dtype=object), 51)
# (array(['GRGND'], dtype=object), 51)
# (array(['GRGNn'], dtype=object), 51)
# (array(['GRGNN'], dtype=object), 51)
# (array(['GRMPd'], dtype=object), 73)
# (array(['GRMPD'], dtype=object), 80)
# (array(['GRMPN'], dtype=object), 51)
# (array(['GRmPD'], dtype=object), 101)
# (array(['GgMRS'], dtype=object), 47)
# (array(['GgMgR'], dtype=object), 7)
# (array(['GgMPd'], dtype=object), 48)
# (array(['GgMPD'], dtype=object), 82)
# (array(['GgMPn'], dtype=object), 26)
# (array(['GgMdn'], dtype=object), 86)
# (array(['GgMdN'], dtype=object), 45)
# (array(['GgMDn'], dtype=object), 7)
# (array(['GgmPd'], dtype=object), 102)
# (array(['GGRGS'], dtype=object), 80)
# (array(['GGRGN'], dtype=object), 51)
# (array(['GGMGR'], dtype=object), 41)
# (array(['GGMPd'], dtype=object), 11)
# (array(['GGMPD'], dtype=object), 0)
# (array(['GGMPN'], dtype=object), 41)
# (array(['GGmrG'], dtype=object), 91)
# (array(['GGmDN'], dtype=object), 115)
# (array(['GGPGR'], dtype=object), 62)
# (array(['GGPmP'], dtype=object), 84)
# ...
# (array(['nMPdN'], dtype=object), 11)
# (array(['nMPDS'], dtype=object), 69)
# (array(['nMPDg'], dtype=object), 7)
# (array(['nMPDn'], dtype=object), 6)
# (array(['nMPnS'], dtype=object), 26)
# (array(['nMPNS'], dtype=object), 60)
# (array(['nMdnS'], dtype=object), 86)
# (array(['nMdNS'], dtype=object), 45)
# (array(['nMDnS'], dtype=object), 7)
# (array(['nmgrS'], dtype=object), 102)
# (array(['nmGrS'], dtype=object), 93)
# (array(['nmGRS'], dtype=object), 106)
# (array(['nmPGM'], dtype=object), 41)
# (array(['nmPdN'], dtype=object), 102)
# (array(['nmPDS'], dtype=object), 101)
# (array(['nmPDP'], dtype=object), 84)
# (array(['nmPDN'], dtype=object), 84)
# (array(['nmDNS'], dtype=object), 115)
# (array(['nPRGR'], dtype=object), 36)
# (array(['nPRGm'], dtype=object), 106)
# (array(['nPgMR'], dtype=object), 47)
# (array(['nPgMP'], dtype=object), 47)
# (array(['nPGRS'], dtype=object), 39)
# (array(['nPGMG'], dtype=object), 41)
# (array(['nPMRS'], dtype=object), 95)
# (array(['nPMRr'], dtype=object), 95)
# (array(['nPMRR'], dtype=object), 95)
# (array(['nPMRg'], dtype=object), 95)
# (array(['nPMRG'], dtype=object), 95)
# (array(['nPMRM'], dtype=object), 95)
# (array(['nPMRm'], dtype=object), 95)
# (array(['nPMRP'], dtype=object), 95)
# (array(['nPMRd'], dtype=object), 95)
# (array(['nPMRD'], dtype=object), 95)
# (array(['nPMRn'], dtype=object), 95)
# (array(['nPMRN'], dtype=object), 95)
# (array(['nPMgS'], dtype=object), 63)
# (array(['nPMgr'], dtype=object), 64)
# (array(['nPMgR'], dtype=object), 31)
# (array(['nPMgg'], dtype=object), 63)
# (array(['nPMgG'], dtype=object), 63)
# (array(['nPMgM'], dtype=object), 63)
# (array(['nPMgm'], dtype=object), 63)
# (array(['nPMgP'], dtype=object), 63)
# (array(['nPMgd'], dtype=object), 63)
# (array(['nPMgD'], dtype=object), 63)
# (array(['nPMgn'], dtype=object), 63)
# (array(['nPMgN'], dtype=object), 63)
# (array(['nPMGr'], dtype=object), 1)
# (array(['nPMGR'], dtype=object), 56)
# (array(['nPMPS'], dtype=object), 47)
# (array(['nPMPr'], dtype=object), 47)
# (array(['nPMPR'], dtype=object), 47)
# (array(['nPMPg'], dtype=object), 47)
# (array(['nPMPG'], dtype=object), 47)
# (array(['nPMPM'], dtype=object), 47)
# (array(['nPMPm'], dtype=object), 47)
# (array(['nPMPP'], dtype=object), 47)
# (array(['nPMPd'], dtype=object), 47)
# (array(['nPMPD'], dtype=object), 47)
# (array(['nPMPn'], dtype=object), 49)
# (array(['nPMPN'], dtype=object), 96)
# (array(['nPmRS'], dtype=object), 101)
# (array(['nPmgr'], dtype=object), 102)
# (array(['nPmGr'], dtype=object), 91)
# (array(['nPmGR'], dtype=object), 106)
# (array(['nPmPG'], dtype=object), 41)
# (array(['nPmPD'], dtype=object), 84)
# (array(['nPdnS'], dtype=object), 47)
# (array(['nPdnP'], dtype=object), 47)
# (array(['nPdNS'], dtype=object), 103)
# (array(['nPDgM'], dtype=object), 7)
# (array(['nPDGP'], dtype=object), 62)
# (array(['nPDPM'], dtype=object), 84)
# (array(['nPDnS'], dtype=object), 6)
# (array(['nPDNS'], dtype=object), 84)
# (array(['nPnSg'], dtype=object), 63)
# (array(['ndMgS'], dtype=object), 86)
# (array(['ndMgr'], dtype=object), 86)
# (array(['ndMgR'], dtype=object), 86)
# (array(['ndMgg'], dtype=object), 86)
# (array(['ndMgG'], dtype=object), 86)
# (array(['ndMgM'], dtype=object), 86)
# (array(['ndMgm'], dtype=object), 86)
# (array(['ndMgP'], dtype=object), 86)
# (array(['ndMgd'], dtype=object), 86)
# (array(['ndMgD'], dtype=object), 86)
# (array(['ndMgn'], dtype=object), 86)
# (array(['ndMgN'], dtype=object), 86)
# (array(['ndMdn'], dtype=object), 86)
# (array(['ndPMS'], dtype=object), 14)
# (array(['ndPMr'], dtype=object), 14)
# (array(['ndPMR'], dtype=object), 14)
# (array(['ndPMg'], dtype=object), 14)
# (array(['ndPMG'], dtype=object), 12)
# (array(['ndPMM'], dtype=object), 14)
# (array(['ndPMm'], dtype=object), 14)
# (array(['ndPMP'], dtype=object), 14)
# (array(['ndPMd'], dtype=object), 14)
# (array(['ndPMD'], dtype=object), 14)
# (array(['ndPMn'], dtype=object), 14)
# (array(['ndPMN'], dtype=object), 14)
# (array(['ndPdn'], dtype=object), 14)
# (array(['ndnPM'], dtype=object), 47)
# (array(['nDRSR'], dtype=object), 36)
# (array(['nDgMg'], dtype=object), 7)
# (array(['nDGPG'], dtype=object), 62)
# (array(['nDMPD'], dtype=object), 7)
# (array(['nDmGr'], dtype=object), 90)
# (array(['nDPGR'], dtype=object), 36)
# (array(['nDPMS'], dtype=object), 23)
# (array(['nDPMr'], dtype=object), 23)
# (array(['nDPMR'], dtype=object), 25)
# (array(['nDPMg'], dtype=object), 29)
# (array(['nDPMG'], dtype=object), 52)
# (array(['nDPMM'], dtype=object), 23)
# (array(['nDPMm'], dtype=object), 23)
# (array(['nDPMP'], dtype=object), 23)
# (array(['nDPMd'], dtype=object), 23)
# (array(['nDPMD'], dtype=object), 23)
# (array(['nDPMn'], dtype=object), 23)
# (array(['nDPMN'], dtype=object), 23)
# (array(['nDPmS'], dtype=object), 101)
# (array(['nDPmr'], dtype=object), 101)
# (array(['nDPmR'], dtype=object), 101)
# (array(['nDPmg'], dtype=object), 105)
# (array(['nDPmG'], dtype=object), 116)
# (array(['nDPmM'], dtype=object), 101)
# (array(['nDPmm'], dtype=object), 101)
# (array(['nDPmP'], dtype=object), 101)
# (array(['nDPmd'], dtype=object), 101)
# (array(['nDPmD'], dtype=object), 101)
# (array(['nDPmn'], dtype=object), 101)
# (array(['nDPmN'], dtype=object), 101)
# (array(['nDPdn'], dtype=object), 73)
# (array(['nDPDS'], dtype=object), 81)
# (array(['nDPDG'], dtype=object), 62)
# (array(['nDPDn'], dtype=object), 6)
# (array(['nDPnS'], dtype=object), 15)
# (array(['nDPNS'], dtype=object), 51)
# (array(['nnSgM'], dtype=object), 26)
# (array(['nnPMR'], dtype=object), 95)
# (array(['nnPMg'], dtype=object), 63)
# (array(['nnPMP'], dtype=object), 47)
# (array(['nndMg'], dtype=object), 86)
# (array(['nndPM'], dtype=object), 14)
# (array(['nnDPM'], dtype=object), 23)
# (array(['nnDPm'], dtype=object), 101)
# (array(['nNSRM'], dtype=object), 51)
# (array(['nNSGM'], dtype=object), 41)
# (array(['nNrGm'], dtype=object), 93)
# (array(['nNRGm'], dtype=object), 106)
# (array(['nNPGR'], dtype=object), 72)
# (array(['nNdMg'], dtype=object), 45)
# (array(['nNdPM'], dtype=object), 11)
# (array(['nNDMP'], dtype=object), 7)
# (array(['nNDmG'], dtype=object), 90)
# (array(['nNDPm'], dtype=object), 111)
# (array(['NSrgM'], dtype=object), 14)
# (array(['NSrgm'], dtype=object), 102)
# (array(['NSrGM'], dtype=object), 11)
# (array(['NSRgM'], dtype=object), 50)
# (array(['NSRGR'], dtype=object), 36)
# (array(['NSRGP'], dtype=object), 72)
# (array(['NSRGN'], dtype=object), 51)
# (array(['NSRMS'], dtype=object), 51)
# (array(['NSRMr'], dtype=object), 51)
# (array(['NSRMR'], dtype=object), 51)
# (array(['NSRMg'], dtype=object), 51)
# (array(['NSRMG'], dtype=object), 51)
# (array(['NSRMM'], dtype=object), 51)
# (array(['NSRMm'], dtype=object), 51)
# (array(['NSRMP'], dtype=object), 51)
# (array(['NSRMd'], dtype=object), 51)
# (array(['NSRMD'], dtype=object), 51)
# (array(['NSRMn'], dtype=object), 51)
# (array(['NSRMN'], dtype=object), 51)
# (array(['NSRmP'], dtype=object), 101)
# (array(['NSgMP'], dtype=object), 26)
# (array(['NSgMd'], dtype=object), 45)
# (array(['NSgMD'], dtype=object), 7)
# (array(['NSGRS'], dtype=object), 41)
# (array(['NSGMS'], dtype=object), 41)
# (array(['NSGMr'], dtype=object), 41)
# (array(['NSGMR'], dtype=object), 41)
# (array(['NSGMg'], dtype=object), 41)
# (array(['NSGMG'], dtype=object), 41)
# (array(['NSGMM'], dtype=object), 41)
# (array(['NSGMm'], dtype=object), 41)
# (array(['NSGMP'], dtype=object), 41)
# (array(['NSGMd'], dtype=object), 41)
# (array(['NSGMD'], dtype=object), 41)
# (array(['NSGMn'], dtype=object), 41)
# (array(['NSGMN'], dtype=object), 41)
# (array(['NSMGP'], dtype=object), 84)
# (array(['NSdnP'], dtype=object), 47)
# (array(['NSDPG'], dtype=object), 36)
# (array(['NSDPM'], dtype=object), 65)
# (array(['NSDPD'], dtype=object), 62)
# (array(['NSnPM'], dtype=object), 95)
# (array(['NSndM'], dtype=object), 86)
# (array(['NSndP'], dtype=object), 14)
# (array(['NSnDP'], dtype=object), 51)
# (array(['NSNPG'], dtype=object), 72)
# (array(['NSNdM'], dtype=object), 45)
# (array(['NSNdP'], dtype=object), 11)
# (array(['NSNDM'], dtype=object), 7)
# (array(['NSNDm'], dtype=object), 90)
# (array(['NSNDP'], dtype=object), 111)
# (array(['NrgMP'], dtype=object), 14)
# (array(['NrgmP'], dtype=object), 102)
# (array(['NrGrS'], dtype=object), 93)
# (array(['NrGMP'], dtype=object), 1)
# (array(['NrGmS'], dtype=object), 93)
# (array(['NrGmr'], dtype=object), 91)
# (array(['NrGmR'], dtype=object), 93)
# (array(['NrGmg'], dtype=object), 93)
# (array(['NrGmG'], dtype=object), 93)
# (array(['NrGmM'], dtype=object), 93)
# (array(['NrGmm'], dtype=object), 93)
# (array(['NrGmP'], dtype=object), 93)
# (array(['NrGmd'], dtype=object), 93)
# (array(['NrGmD'], dtype=object), 93)
# (array(['NrGmn'], dtype=object), 93)
# (array(['NrGmN'], dtype=object), 93)
# (array(['NRSRG'], dtype=object), 36)
# (array(['NRgMP'], dtype=object), 50)
# (array(['NRGRS'], dtype=object), 107)
# (array(['NRGmS'], dtype=object), 106)
# (array(['NRGmr'], dtype=object), 106)
# (array(['NRGmR'], dtype=object), 106)
# (array(['NRGmg'], dtype=object), 106)
# (array(['NRGmG'], dtype=object), 106)
# (array(['NRGmM'], dtype=object), 106)
# (array(['NRGmm'], dtype=object), 106)
# (array(['NRGmP'], dtype=object), 106)
# (array(['NRGmd'], dtype=object), 106)
# (array(['NRGmD'], dtype=object), 106)
# (array(['NRGmn'], dtype=object), 106)
# (array(['NRGmN'], dtype=object), 106)
# (array(['NRGPD'], dtype=object), 37)
# (array(['NRGPN'], dtype=object), 72)
# (array(['NRGNS'], dtype=object), 51)
# (array(['NRMPd'], dtype=object), 73)
# (array(['NRMPD'], dtype=object), 69)
# (array(['NRMPN'], dtype=object), 59)
# (array(['NRmPD'], dtype=object), 101)
# (array(['NgMRS'], dtype=object), 47)
# (array(['NgMgR'], dtype=object), 7)
# (array(['NgMPd'], dtype=object), 48)
# (array(['NgMPD'], dtype=object), 82)
# (array(['NgMPn'], dtype=object), 26)
# (array(['NgMdn'], dtype=object), 86)
# (array(['NgMdN'], dtype=object), 45)
# (array(['NgMDn'], dtype=object), 7)
# (array(['NgmPd'], dtype=object), 102)
# (array(['NGRGS'], dtype=object), 80)
# (array(['NGRGN'], dtype=object), 51)
# (array(['NGMGR'], dtype=object), 41)
# (array(['NGMPd'], dtype=object), 11)
# (array(['NGMPD'], dtype=object), 0)
# (array(['NGMPN'], dtype=object), 41)
# (array(['NGmrG'], dtype=object), 91)
# (array(['NGmDN'], dtype=object), 115)
# (array(['NGPGR'], dtype=object), 62)
# (array(['NGPmP'], dtype=object), 84)
# (array(['NGPDS'], dtype=object), 37)
# (array(['NGPNS'], dtype=object), 72)
# (array(['NMgrS'], dtype=object), 14)
# (array(['NMgRS'], dtype=object), 19)
# (array(['NMGrS'], dtype=object), 1)
# (array(['NMGRS'], dtype=object), 41)
# (array(['NMGRG'], dtype=object), 56)
# (array(['NMGPm'], dtype=object), 84)
# (array(['NMPgM'], dtype=object), 47)
# (array(['NMPdn'], dtype=object), 78)
# (array(['NMPdN'], dtype=object), 11)
# (array(['NMPDS'], dtype=object), 69)
# (array(['NMPDg'], dtype=object), 7)
# (array(['NMPDn'], dtype=object), 6)
# (array(['NMPnS'], dtype=object), 26)
# (array(['NMPNS'], dtype=object), 60)
# (array(['NMdnS'], dtype=object), 86)
# (array(['NMdNS'], dtype=object), 45)
# (array(['NMDnS'], dtype=object), 7)
# (array(['NmgrS'], dtype=object), 102)
# (array(['NmGrS'], dtype=object), 93)
# (array(['NmGRS'], dtype=object), 106)
# (array(['NmPGM'], dtype=object), 41)
# (array(['NmPdN'], dtype=object), 102)
# (array(['NmPDS'], dtype=object), 101)
# (array(['NmPDP'], dtype=object), 84)
# (array(['NmPDN'], dtype=object), 84)
# (array(['NmDNS'], dtype=object), 115)
# (array(['NPRGR'], dtype=object), 36)
# (array(['NPRGm'], dtype=object), 106)
# (array(['NPgMR'], dtype=object), 47)
# (array(['NPGRS'], dtype=object), 72)
# (array(['NPGRr'], dtype=object), 72)
# (array(['NPGRR'], dtype=object), 72)
# (array(['NPGRg'], dtype=object), 72)
# (array(['NPGRG'], dtype=object), 72)
# (array(['NPGRM'], dtype=object), 72)
# (array(['NPGRm'], dtype=object), 72)
# (array(['NPGRP'], dtype=object), 72)
# (array(['NPGRd'], dtype=object), 72)
# (array(['NPGRD'], dtype=object), 72)
# (array(['NPGRn'], dtype=object), 72)
# (array(['NPGRN'], dtype=object), 72)
# (array(['NPGMG'], dtype=object), 41)
# (array(['NPGPN'], dtype=object), 72)
# (array(['NPMRS'], dtype=object), 100)
# (array(['NPMgS'], dtype=object), 63)
# (array(['NPMgr'], dtype=object), 14)
# (array(['NPMgR'], dtype=object), 29)
# (array(['NPMGr'], dtype=object), 1)
# (array(['NPMGR'], dtype=object), 56)
# (array(['NPMPg'], dtype=object), 47)
# (array(['NPmRS'], dtype=object), 101)
# (array(['NPmgr'], dtype=object), 102)
# (array(['NPmGr'], dtype=object), 91)
# (array(['NPmGR'], dtype=object), 106)
# (array(['NPmPG'], dtype=object), 41)
# (array(['NPmPD'], dtype=object), 84)
# (array(['NPdnS'], dtype=object), 78)
# (array(['NPdNS'], dtype=object), 103)
# (array(['NPDgM'], dtype=object), 7)
# (array(['NPDGP'], dtype=object), 62)
# (array(['NPDPM'], dtype=object), 84)
# (array(['NPDnS'], dtype=object), 6)
# (array(['NPDNS'], dtype=object), 84)
# (array(['NPnSg'], dtype=object), 63)
# (array(['NdMgS'], dtype=object), 45)
# (array(['NdMgr'], dtype=object), 45)
# (array(['NdMgR'], dtype=object), 45)
# (array(['NdMgg'], dtype=object), 45)
# (array(['NdMgG'], dtype=object), 45)
# (array(['NdMgM'], dtype=object), 45)
# (array(['NdMgm'], dtype=object), 45)
# (array(['NdMgP'], dtype=object), 45)
# (array(['NdMgd'], dtype=object), 45)
# (array(['NdMgD'], dtype=object), 45)
# (array(['NdMgn'], dtype=object), 45)
# (array(['NdMgN'], dtype=object), 45)
# (array(['NdMdN'], dtype=object), 45)
# (array(['NdPMS'], dtype=object), 11)
# (array(['NdPMr'], dtype=object), 11)
# (array(['NdPMR'], dtype=object), 11)
# (array(['NdPMg'], dtype=object), 12)
# (array(['NdPMG'], dtype=object), 11)
# (array(['NdPMM'], dtype=object), 11)
# (array(['NdPMm'], dtype=object), 11)
# (array(['NdPMP'], dtype=object), 11)
# (array(['NdPMd'], dtype=object), 11)
# (array(['NdPMD'], dtype=object), 11)
# (array(['NdPMn'], dtype=object), 11)
# (array(['NdPMN'], dtype=object), 11)
# (array(['NdPdN'], dtype=object), 11)
# (array(['NdnPM'], dtype=object), 47)
# (array(['NDRSR'], dtype=object), 36)
# (array(['NDgMg'], dtype=object), 7)
# (array(['NDgMD'], dtype=object), 7)
# (array(['NDGPG'], dtype=object), 62)
# (array(['NDMgR'], dtype=object), 7)
# (array(['NDMPS'], dtype=object), 7)
# (array(['NDMPr'], dtype=object), 7)
# (array(['NDMPR'], dtype=object), 7)
# (array(['NDMPg'], dtype=object), 7)
# (array(['NDMPG'], dtype=object), 7)
# (array(['NDMPM'], dtype=object), 7)
# (array(['NDMPm'], dtype=object), 7)
# (array(['NDMPP'], dtype=object), 7)
# (array(['NDMPd'], dtype=object), 7)
# (array(['NDMPD'], dtype=object), 7)
# (array(['NDMPn'], dtype=object), 7)
# (array(['NDMPN'], dtype=object), 7)
# (array(['NDMDn'], dtype=object), 7)
# (array(['NDmGS'], dtype=object), 90)
# (array(['NDmGr'], dtype=object), 90)
# (array(['NDmGR'], dtype=object), 90)
# (array(['NDmGg'], dtype=object), 90)
# (array(['NDmGG'], dtype=object), 90)
# (array(['NDmGM'], dtype=object), 90)
# (array(['NDmGm'], dtype=object), 90)
# (array(['NDmGP'], dtype=object), 90)
# (array(['NDmGd'], dtype=object), 90)
# (array(['NDmGD'], dtype=object), 90)
# (array(['NDmGn'], dtype=object), 90)
# (array(['NDmGN'], dtype=object), 90)
# (array(['NDmDN'], dtype=object), 90)
# (array(['NDPRG'], dtype=object), 106)
# (array(['NDPGR'], dtype=object), 36)
# (array(['NDPGM'], dtype=object), 41)
# (array(['NDPMR'], dtype=object), 84)
# (array(['NDPMg'], dtype=object), 29)
# (array(['NDPMG'], dtype=object), 53)
# (array(['NDPmS'], dtype=object), 111)
# (array(['NDPmr'], dtype=object), 91)
# (array(['NDPmR'], dtype=object), 112)
# (array(['NDPmg'], dtype=object), 102)
# (array(['NDPmG'], dtype=object), 110)
# (array(['NDPmM'], dtype=object), 111)
# (array(['NDPmm'], dtype=object), 111)
# (array(['NDPmP'], dtype=object), 43)
# (array(['NDPmd'], dtype=object), 111)
# (array(['NDPmD'], dtype=object), 110)
# (array(['NDPmn'], dtype=object), 111)
# (array(['NDPmN'], dtype=object), 111)
# (array(['NDPdN'], dtype=object), 102)
# (array(['NDPDG'], dtype=object), 62)
# (array(['NDPDP'], dtype=object), 84)
# (array(['NDPDN'], dtype=object), 84)
# (array(['NDPNS'], dtype=object), 41)
# (array(['NnSgM'], dtype=object), 26)
# (array(['NnPMR'], dtype=object), 95)
# (array(['NnPMg'], dtype=object), 63)
# (array(['NnPMP'], dtype=object), 47)
# (array(['NndMg'], dtype=object), 86)
# (array(['NndPM'], dtype=object), 14)
# (array(['NnDPM'], dtype=object), 23)
# (array(['NnDPm'], dtype=object), 101)
# (array(['NNSRM'], dtype=object), 51)
# (array(['NNSGM'], dtype=object), 41)
# (array(['NNrGm'], dtype=object), 93)
# (array(['NNRGm'], dtype=object), 106)
# (array(['NNPGR'], dtype=object), 72)
# (array(['NNdMg'], dtype=object), 45)
# (array(['NNdPM'], dtype=object), 11)
# (array(['NNDMP'], dtype=object), 7)
# (array(['NNDmG'], dtype=object), 90)
# (array(['NNDPm'], dtype=object), 111)
# 3690 3690
